# %%
ph={}
ph1={}
n=int(input("Enter the number of people:"))
for i in range(0,n):
    a=input("Enter the name:")
    b=input("Enter the number:")
    ph[a]=b
for i in sorted(ph):
    ph1[i]=ph[i]
print(ph1)
